# %% [markdown]
# # Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/airbnb_project
# Out:
# /content/drive/MyDrive/airbnb_project

# %%
# !git config --global user.name "JaviTest01Test"
# !git config --global user.email "javitest01test@gmail.com"

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/airbnb_project/.git/

# %%
# !git remote add origin https://github.com/JaviTest01Test/airbnb.git
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git remote set-url origin https://JaviTest01Test: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@github.com/JaviTest01Test/airbnb.git
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git branch
# Out:
# * master

# %%
# !git add .
# !git commit -m "DockerFile 11"
# Out:
# [master d9d2715] DockerFile 11
#  2 files changed, 17 insertions(+), 1 deletion(-)
#  create mode 100644 Dockerfile.txt

# %%
# !git push -u origin master:master
# Out:
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 1.37 KiB | 175.00 KiB/s, done.
# Total 5 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/JaviTest01Test/airbnb.git
#    dd566cb..d9d2715  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %% [markdown]
# # GitHub Actions

# %%
with open('/content/drive/MyDrive/airbnb_project/requirements.txt', 'w') as f:
    f.write("pyspark\npytest\n")

# %%
# !ls -la
# Out:
# total 30
# drwx------ 3 root root 4096 Jan 22 10:32 datasets
# -rw------- 1 root root  675 Jan 24 20:18 Dockerfile.txt
# drwx------ 8 root root 4096 Jan 24 20:19 .git
# drwx------ 3 root root 4096 Jan 24 08:09 .github
# drwx------ 2 root root 4096 Jan 23 19:16 notebooks
# -rw------- 1 root root   15 Jan 24 08:13 requirements.txt
# drwx------ 3 root root 4096 Jan 23 19:08 src
# drwx------ 5 root root 4096 Jan 23 20:53 tables
# drwx------ 4 root root 4096 Jan 23 15:05 tests
