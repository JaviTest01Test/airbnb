# %% [markdown]
# # Pushing Git

# %%
# %cd /content/drive/MyDrive/airbnb_project
# Out:
# /content/drive/MyDrive/airbnb_project

# %%
# !git config --global user.name "JaviTest01Test"
# !git config --global user.email "javitest01test@gmail.com"

# %%
# !git add .
# !git commit -m "Final 6"
# Out:
# [master 8b4e5fa] Final 5
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite notebooks/git_operations.ipynb (99%)

# %%
# !git push -u po master:master
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %% [markdown]
# # Initializing Git

# %%
# !git remote add origin https://github.com/JaviTest01Test/airbnb.git
# Out:
# error: remote origin already exists.

# %%
# !git remote set-url origin https://JaviTest01Test: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@github.com/JaviTest01Test/airbnb.git

# %% [markdown]
# # GitHub Actions

# %%
with open('/content/drive/MyDrive/airbnb_project/requirements.txt', 'w') as f:
    f.write("pyspark\npytest\n")

# %%
import os

# Set your GitHub username and Personal Access Token
github_username = 'JaviTest01Test'  # Replace with your GitHub username
github_token = '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'  # Replace with the Personal Access Token you generated

# Configure git with your username and email
os.system(f'git config --global user.name "{github_username}"')
os.system(f'git config --global user.email "{github_username}@gmail.com"')  # Replace with your email

# Authenticate with GitHub using your token
os.system(f'git remote set-url origin https://{github_username}:{github_token}@github.com/{github_username}/airbnb.git')
# Out:
# 0

# %%
# !git push origin master
# Out:
# Enumerating objects: 371, done.
# Counting objects: 100% (371/371), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (231/231), done.
# Writing objects: 100% (302/302), 361.28 KiB | 339.00 KiB/s, done.
# Total 302 (delta 74), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (74/74), completed with 4 local objects.
# To https://github.com/JaviTest01Test/airbnb.git
#    b5c609a..8b4e5fa  master -> master

# %%
# !git remote set-url origin https://github.com/JaviTest01Test/airbnb.git

# %%
# !git credential-manager erase
# Out:
# git: 'credential-manager' is not a git command. See 'git --help'.

# %%
# !rm -rf ~/.gitconfig

# %%
# !git remote -v
# Out:
# origin	https://JaviTest01Test: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@github.com/JaviTest01Test/airbnb.git (fetch)
# origin	https://JaviTest01Test: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@github.com/JaviTest01Test/airbnb.git (push)
# po	https://github.com/JaviTest01Test/airbnb.git (fetch)
# po	https://github.com/JaviTest01Test/airbnb.git (push)
