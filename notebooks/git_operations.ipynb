# %% [markdown]
# # Libraries

# %%
# %cd /content/drive/MyDrive/airbnb_project
# Out:
# /content/drive/MyDrive/airbnb_project

# %%
# !git config --global user.name "JaviTest01Test"
# !git config --global user.email "javitest01test@gmail.com"

# %%
# !git remote add origin https://github.com/JaviTest01Test/airbnb.git
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git remote set-url origin https://JaviTest01Test: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@github.com/JaviTest01Test/airbnb.git

# %%
# !git add .
# !git commit -m "New Dockerfile"
# Out:
# [master 6b72993] New Dockerfile
#  22 files changed, 7 insertions(+), 7 deletions(-)
#  rewrite notebooks/git_operations.ipynb (95%)
#  rewrite notebooks/medallion_architecture_airbnb.ipynb (98%)
#  rewrite notebooks/tests.ipynb (94%)
#  rename tables/bronze/bronze_listings_details/{.part-00000-85d1278f-add8-4989-9c2d-b6a3e1afcb7a-c000.snappy.parquet.crc => .part-00000-4704fd57-eae4-4443-91d0-0b27e17cfa82-c000.snappy.parquet.crc} (91%)
#  rename tables/bronze/bronze_listings_details/{.part-00001-85d1278f-add8-4989-9c2d-b6a3e1afcb7a-c000.snappy.parquet.crc => .part-00001-4704fd57-eae4-4443-91d0-0b27e17cfa82-c000.snappy.parquet.crc} (66%)
#  rename tables/bronze/bronze_listings_details/{part-00000-85d1278f-add8-4989-9c2d-b6a3e1afcb7a-c000.snappy.parquet => part-00000-4704fd57-eae4-4443-91d0-0b27e17cfa82-c000.snappy.parquet} (99%)
#  rename tables/bronze/bronze_listings_details/{part-00001-85d1278f-add8-4989-9c2d-b6a3e1afcb7a-c000.snappy.parquet => part-00001-4704fd57-eae4-4443-91d0-0b27e17cfa82-c000.snappy.parquet} (97%)
#  create mode 100644 tables/bronze/neighbourhoods/.part-00000-1cb9e75f-2ab2-4a77-8757-41f3f49093c0-c000.snappy.parquet.crc
#  delete mode 100644 tables/bronze/neighbourhoods/.part-00000-d750d7b4-cf62-4f1b-bec2-090a53c60b96-c000.snappy.parquet.crc
#  rename tables/bronze/neighbourhoods/{part-00000-d750d7b4-cf62-4f1b-bec2-090a53c60b96-c000.snappy.parquet => part-00000-1cb9e75f-2ab2-4a77-8757-41f3f49093c0-c000.snappy.parquet} (86%)
#  create mode 100644 tables/gold/dasboard_ng_ratings/._SUCCESS.crc
#  create mode 100644 tables/gold/dasboard_ng_ratings/.part-00000-7c4f1fce-cbf9-4a83-83c6-8e78a346b3fe-c000.snappy.parquet.crc
#  create mode 100644 tables/gold/dasboard_ng_ratings/_SUCCESS
#  create mode 100644 tables/gold/dasboard_ng_ratings/part-00000-7c4f1fce-cbf9-4a83-83c6-8e78a346b3fe-c000.snappy.parquet
#  create mode 100644 tables/silver/silver_listings_details/._SUCCESS.crc
#  create mode 100644 tables/silver/silver_listings_details/.part-00000-5d2b25cb-187e-4708-aa29-b9db711dbf99-c000.snappy.parquet.crc
#  create mode 100644 tables/silver/silver_listings_details/.part-00001-5d2b25cb-187e-4708-aa29-b9db711dbf99-c000.snappy.parquet.crc
#  create mode 100644 tables/silver/silver_listings_details/_SUCCESS
#  create mode 100644 tables/silver/silver_listings_details/part-00000-5d2b25cb-187e-4708-aa29-b9db711dbf99-c000.snappy.parquet
#  create mode 100644 tables/silver/silver_listings_details/part-00001-5d2b25cb-187e-4708-aa29-b9db711dbf99-c000.snappy.parquet

# %%
# !git push -u origin master:master
# Out:
# Enumerating objects: 43, done.
# Counting objects: 100% (43/43), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (28/28), done.
# Writing objects: 100% (30/30), 125.82 KiB | 1.20 MiB/s, done.
# Total 30 (delta 10), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (10/10), completed with 6 local objects.
# To https://github.com/JaviTest01Test/airbnb.git
#    c444c89..6b72993  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %% [markdown]
# # GitHub Actions

# %%
with open('/content/drive/MyDrive/airbnb_project/requirements.txt', 'w') as f:
    f.write("pyspark\npytest\n")
