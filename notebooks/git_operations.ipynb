# %% [markdown]
# # Pushing Git

# %%
# %cd /content/drive/MyDrive/airbnb_project
# Out:
# /content/drive/MyDrive/airbnb_project

# %%
# !git config --global user.name "JaviTest01Test"
# !git config --global user.email "javitest01test@gmail.com"

# %%
# !git add .
# !git commit -m "Test ETL Pipeline"
# Out:
# [master 7cfd9d4] Test ETL Pipeline
#  10 files changed, 140 insertions(+), 4 deletions(-)
#  rewrite notebooks/git_operations.ipynb (95%)
#  create mode 100644 notebooks/main.ipynb
#  delete mode 100644 notebooks/prueba.ipynb
#  rewrite notebooks/tests.ipynb (84%)
#  create mode 100644 src/__pycache__/etl_pipeline.cpython-311.pyc
#  create mode 100644 src/etl_pipeline.py
#  create mode 100644 tests/__pycache__/test_etl_pipeline.cpython-311-pytest-8.3.4.pyc
#  create mode 100644 tests/test_etl_pipeline.py

# %%
# !git push -u origin master:master
# Out:
# Enumerating objects: 29, done.
# Counting objects: 100% (29/29), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (17/17), done.
# Writing objects: 100% (18/18), 38.65 KiB | 507.00 KiB/s, done.
# Total 18 (delta 5), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (5/5), completed with 5 local objects.
# To https://github.com/JaviTest01Test/airbnb.git
#    6cd374c..7cfd9d4  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %% [markdown]
# # Initializing Git

# %%
# !git remote add origin https://github.com/JaviTest01Test/airbnb.git
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git remote set-url origin https://JaviTest01Test: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@github.com/JaviTest01Test/airbnb.git

# %% [markdown]
# # GitHub Actions

# %%
with open('/content/drive/MyDrive/airbnb_project/requirements.txt', 'w') as f:
    f.write("pyspark\npytest\n")
