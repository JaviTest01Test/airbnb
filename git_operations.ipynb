# %% [markdown]
# # Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/airbnb_project
# Out:
# /content/drive/MyDrive/airbnb_project

# %%
# !git config --global user.name "JaviTest01Test"
# !git config --global user.email "javitest01test@gmail.com"

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/airbnb_project/.git/

# %%
# !git remote add origin https://github.com/JaviTest01Test/airbnb.git

# %%
# !git branch

# %%
# !git add .
# !git commit -m "First commit"
# !git push -u origin main
# Out:
# [master (root-commit) 0a24f39] First commit
#  28 files changed, 9070 insertions(+)
#  create mode 100644 datasets/dashboard_ng_ratings.csv
#  create mode 100644 datasets/listings_details.csv
#  create mode 100644 datasets/listings_details.xlsx
#  create mode 100644 datasets/listings_details_cleaned.csv
#  create mode 100644 datasets/neighbourhoods.csv
#  create mode 100644 datasets/neighbourhoods.xlsx
#  create mode 100644 git_operations.ipynb
#  create mode 100644 medallion_architecture_airbnb.ipynb
#  create mode 100644 tables/bronze/bronze_listings_details/._SUCCESS.crc
#  create mode 100644 tables/bronze/bronze_listings_details/.part-00000-493793c7-2dfd-417e-92db-aee48813d027-c000.snappy.parquet.crc
#  create mode 100644 tables/bronze/bronze_listings_details/.part-00001-493793c7-2dfd-417e-92db-aee48813d027-c000.snappy.parquet.crc
#  create mode 100644 tables/bronze/bronze_listings_details/_SUCCESS
#  create mode 100644 tables/bronze/bronze_listings_details/part-00000-493793c7-2dfd-417e-92db-aee48813d027-c000.snappy.parquet
#  create mode 100644 tables/bronze/bronze_listings_details/part-00001-493793c7-2dfd-417e-92db-aee48813d027-c000.snappy.parquet
#  create mode 100644 tables/bronze/neighbourhoods/._SUCCESS.crc
#  create mode 100644 tables/bronze/neighbourhoods/.part-00000-a1e3e7b9-797a-45cc-b0f3-411edd359ac0-c000.snappy.parquet.crc
#  create mode 100644 tables/bronze/neighbourhoods/_SUCCESS
#  create mode 100644 tables/bronze/neighbourhoods/part-00000-a1e3e7b9-797a-45cc-b0f3-411edd359ac0-c000.snappy.parquet
#  create mode 100644 tables/gold/dasboard_ng_ratings/._SUCCESS.crc
#  create mode 100644 tables/gold/dasboard_ng_ratings/.part-00000-84885a94-74cc-4929-babd-cbd7c0fa40d1-c000.snappy.parquet.crc
#  create mode 100644 tables/gold/dasboard_ng_ratings/_SUCCESS
#  create mode 100644 tables/gold/dasboard_ng_ratings/part-00000-84885a94-74cc-4929-babd-cbd7c0fa40d1-c000.snappy.parquet
#  create mode 100644 tables/silver/silver_listings_details/._SUCCESS.crc
#  create mode 100644 tables/silver/silver_listings_details/.part-00000-053e1c6f-e21e-4973-a2c2-3da05aaf0977-c000.snappy.parquet.crc
#  create mode 100644 tables/silver/silver_listings_details/.part-00001-053e1c6f-e21e-4973-a2c2-3da05aaf0977-c000.snappy.parquet.crc
#  create mode 100644 tables/silver/silver_listings_details/_SUCCESS
#  create mode 100644 tables/silver/silver_listings_details/part-00000-053e1c6f-e21e-4973-a2c2-3da05aaf0977-c000.snappy.parquet
#  create mode 100644 tables/silver/silver_listings_details/part-00001-053e1c6f-e21e-4973-a2c2-3da05aaf0977-c000.snappy.parquet
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/JaviTest01Test/airbnb.git'
